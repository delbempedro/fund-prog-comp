# %%
def ack(m,n):
  if m>0 and n>0:
    return ack(m-1,ack(m,n-1))
  elif n==0 and m > 0:
    return ack(m-1,1)
  else:
    return n + 1

# %%
m,n = input().split()
m,n = int(m),int(n)
# Out:
# 2 4

# %%
print(ack(m,n))
# Out:
# 11
