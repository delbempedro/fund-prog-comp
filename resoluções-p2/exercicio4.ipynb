# %%
def caixa_eletronico(valor):
  f = {}
  
  res = ced.copy()
  for vc in res.keys():
    control = 0
    if valor < 10 and valor != 0:
        if valor == 9:
          ced[5] = 1
          ced[2] = 2
        if valor == 8:
          ced[2] = 4
        if valor == 7:
          ced[5] = 1
          ced[2] = 1
        if valor == 6:
          ced[2] = 3
        if valor == 5:
          ced[5] = 1
        if valor == 4:
          ced[2] = 2
        if valor == 3:
          ced[2] = 1
        if valor == 2:
          ced[2] = 1
        control = 1
    else:
        if control == 0:
          q, r = valor // vc, valor % vc
          ced[vc] = q
          valor = r

  for i in ced:
    if ced[i] != 0:
      f[i] = ced[i]
  
  return f

# %% [markdown]
# #erro

# %%
def caixa_eletronico(valor):
  f = {}
  
  while valor - 100 >= 0:
    valor = valor - 100
    ced[100] = ced[100] + 1
  while valor - 50 >= 0:
      valor = valor - 50
      ced[50] = ced[50] + 1
  while valor - 20 >= 0:
      valor = valor - 20
      ced[20] = ced[20] + 1
  while valor - 10 >= 0:
      valor = valor - 10
      ced[10] = ced[10] + 1
  while valor - 5 >= 0:
      valor = valor - 5
      ced[5] = ced[5] + 1
  while valor - 2 >= 0:
      valor = valor - 2
      ced[2] = ced[2] + 1

  for i in ced:
    if ced[i] != 0:
      f[i] = ced[i]
  
  return f

# %%
ced = {100: 0,50: 0,20: 0, 10: 0, 5: 0,2: 0}

# %%
valor = 158

# %%
print(caixa_eletronico(valor))
# Out:
# {100: 1, 50: 1, 5: 1, 2: 4}

# %%
valor = 158

res = ced.copy()
for vc in res.keys():
    if valor < 10 and valor != 0:
      #q, r = valor // vc, valor % vc
      print('!')
      if (valor % 5)%2 == 0:
        #divide por 5 e depois por 2
        print(5,valor)
        ced[5] = 1
        ced[2] = (valor % 5)//2
      else:
        #divide só por 2
        print(2,valor)
        ced[2] = valor//2
      break
    else:
      q, r = valor // vc, valor % vc
      ced[vc] = q
      valor = r

print(ced)
# Out:
# !
# 2 8
# {100: 1, 50: 1, 20: 0, 10: 0, 5: 1, 2: 4}

# %%
valor = 151
ced = {100: 0,50: 0,20: 0, 10: 0, 5: 0,2: 0}

res = ced.copy()
for vc in res.keys():
  control = 0
  if valor < 10 and valor != 0:
      if valor == 9:
        ced[5] = 1
        ced[2] = 2
      if valor == 8:
        ced[2] = 4
      if valor == 7:
        ced[5] = 1
        ced[2] = 1
      if valor == 6:
        ced[2] = 3
      if valor == 5:
        ced[5] = 1
      if valor == 4:
        ced[2] = 2
      if valor == 3:
        ced[2] = 1
      if valor == 2:
        ced[2] = 1
      control = 1
  else:
      if control == 0:
        q, r = valor // vc, valor % vc
        ced[vc] = q
        valor = r

print(ced)
# Out:
# {100: 1, 50: 1, 20: 0, 10: 0, 5: 0, 2: 0}

# %%
for i in ced.values():
  print(i)
# Out:
# 8
# 0
# 4
# 0
# 2
# 2

# %%
for i in ced.keys():
  print(i)
# Out:
# 100
# 50
# 20
# 10
# 5
# 2
