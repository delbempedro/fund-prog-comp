# %% [markdown]
# Dado um número natural nn. Faça um programa para calcular o n-ésimo termo da Sequência Fibonacci.
# Sendo, F(0) = 0F(0)=0, F(1) = 1F(1)=1 e F(n)= F(n-1)+F(n-2)F(n)=F(n−1)+F(n−2) para n\gt 1n>1.

# %%
n = int(input())
# Out:
# 5

# %%
x = 0

# %%
valor = 0

# %%
while (x == n):
  x += 1

# %%
print (valor)
# Out:
# 0

# %% [markdown]
# n = int(input())
#
# f0, f1 = 0,1
#
# if n == 0:
# 	fn = f0
# elif n == 1:
# 	fn = f1
# else:
# 	for i in range(2, n+1):
# 		fn = f0 + f1
# 		f0 = f1
# 		f1 = fn
#
# print(fn)

# %% [markdown]
# n = int(input())
#
# x = 0
#
# valor = 0
#
# a = 0
# b = 1
#
# salvar = 0
#
# for x in range (2, n-1):
# 	if n == 0:
# 		break
# 	x += 1
# 	valor = a + b
# 	salvar = b
# 	b = a + b
# 	a = salvar
#
# print (valor)
