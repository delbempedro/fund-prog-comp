# %% [markdown]
# n = int(input())
#
# x = 0
#
# a = 1
#
# for i in range(1,n+1):
# 	d = a*(a + 1)*(a + 2)
# 	if n == d:
# 		x = 1
# 	else:
# 		a += 1
#
# if x == 0:
# 	print("não triangular")
# else:
# 	print("triangular")
