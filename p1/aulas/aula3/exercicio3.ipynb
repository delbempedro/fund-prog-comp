# %% [markdown]
# n = int(input())
#
# sinal = 1
#
# resultado = 0
#
# s = 1
#
# for i in range(1, n+1):
# 	divisao = (1/i)*sinal
# 	sinal = sinal*(-1)
# 	resultado = resultado + divisao
#
# print("%.2f"%resultado)
