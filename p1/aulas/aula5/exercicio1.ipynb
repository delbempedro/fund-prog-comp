# %% [markdown]
# Faça um programa que leia uma matriz quadrada A de ordem 3 e calcule o seu traço, isto é, a soma de seus elementos da diagonal.
#
# tr(A) = \sum_i a_{ii}tr(A)=∑
# i
# ​
#  a
# ii
# ​
#   .

# %%
matriz = [0,0,0]

# %%
for i in range (3):
	matriz[i] = [float(i) for i in input().split()]

# %%
soma = 0

# %%
for i in range (3):
	soma += matriz[i][i]

# %%
print("%.2f"%soma)
