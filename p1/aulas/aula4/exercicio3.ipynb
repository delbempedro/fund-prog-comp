# %% [markdown]
# #resposta minha

# %%
vetor = [int(i) for i in input().split()]
x = int(input())

ind = -1

for i in range (len(vetor)):
	if vetor[i] == x:
		ind = i
		break

print(ind)

# %% [markdown]
# #resposta professor

# %%
l = input().split()
x = input()

resp = - 1

if x in l:
	resp = l.index(x)
	
print(resp)
