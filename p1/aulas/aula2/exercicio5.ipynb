# %%
n = input()
n = int(n)
n2 = 0
# Out:
# 21

# %%
x = "nada"

# %%
if n <= 10:
  if n == 0:
    print("zero")
  if n == 1:
    print("um")
  if n == 2:
    print("dois")
  if n == 3:
    print("três")
  if n == 4:
    print("quatro")
  if n == 5:
    print("cinco")
  if n == 6:
    print("seis")
  if n == 7:
    print("sete")
  if n == 8:
    print("oito")
  if n == 9:
    print("nove")
  if n == 10:
    print("dez")

if n <= 20:
  n2 = n - 10
  if n2 == 1:
    print("onze")
  if n2 == 2:
    print("doze")
  if n2 == 3:
    print("treze")
  if n2 == 4:
    print("quatorze")
  if n2 == 5:
    print("quinze")
  if n2 == 6:
    print("dezesseis")
  if n2 == 7:
    print("dezessete")
  if n2 == 8:
    print("dezoito")
  if n2 == 9:
    print("dezenove")
  if n == 20:
    print("vinte")

if 20 < n < 30:
  n2 = n - 20
  if n2 == 1:
    x = "um"
  if n2 == 2:
    x = "dois"
  if n2 == 3:
    x = "três"
  if n2 == 4:
    x = "quatro"
  if n2 == 5:
    x = "cinco"
  if n2 == 6:
    x = "seis"
  if n2 == 7:
    x = "sete"
  if n2 == 8:
    x = "oito"
  if n2 == 9:
    x = "nove"
  print("vinte" + " " + "e" + " " + x)

if 30 < n < 40:
  n2 = n - 30
  if n2 == 1:
    x = "um"
  if n2 == 2:
    x = "dois"
  if n2 == 3:
    x = "três"
  if n2 == 4:
    x = "quatro"
  if n2 == 5:
    x = "cinco"
  if n2 == 6:
    x = "seis"
  if n2 == 7:
    x = "sete"
  if n2 == 8:
    x = "oito"
  if n2 == 9:
    x = "nove"
  print("trinta" + " " + "e" + " " + x)

if n > 40:
  n2 = n - 40
  if n2 == 1:
    x = "um"
  if n2 == 2:
    x = "dois"
  if n2 == 3:
    x = "três"
  if n2 == 4:
    x = "quatro"
  if n2 == 5:
    x = "cinco"
  if n2 == 6:
    x = "seis"
  if n2 == 7:
    x = "sete"
  if n2 == 8:
    x = "oito"
  if n2 == 9:
    x = "nove"
  print("quarenta" + " " + "e" + " " + x)

if n == 30:
  print("trinta")
if n == 40:
  print("quarenta")
# Out:
# vinte e um
# trinta e um
