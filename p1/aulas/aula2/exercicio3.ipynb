# %% [markdown]
# a = r cos theta
# b = r sen theta

# %%
import math

# %%
r, theta = input().split()
r, theta = float(r), float(theta)
# Out:
# 10.28 5.07

# %%
a = float(r*(math.cos(theta)))
b = float(r*(math.sin(theta)))
a = "%.2f"%a
a = str(a)
c = 0

# %%
if b < 0:
  b = (b**2)**(0.5)
  c = 1

# %%
b = "%.2f"%b
b = str(b)

# %%
if c == 0:
  print (a + " " + "+" + " " + b + "i")
elif c == 1:
  print (a + " " + "-" + " " + b + "i")
# Out:
# 3.60 - 9.63i
