# %% [markdown]
# Dados o centro (x, y, z)(x,y,z) e o raio RR de uma esfera, calcule a quantidade NN de coordenadas inteiras (x_i, y_i, z_i)(x
# i
# ​
#  ,y
# i
# ​
#  ,z
# i
# ​
#  ) - onde os valores de x_ix
# i
# ​
#  , y_iy
# i
# ​
#   e z_iz
# i
# ​
#   são números inteiros - que ocorrem no interior (incluindo superfície) da esfera.

# %%
x,y,z,r = input().split()
x,y,z,r = int(x),int(y),int(z),float(r)
# Out:
#  0 0 0 1

# %%
r = int(r)

# %%
cx = 0
cy = 0
cz = 0

# %%
r3D = (r**2 + r**2 + r**2)**(1/2)

# %%
pontos = 0

# %%
for X in range (-r,r+1):
	cx = X
	for Y in range (-r,r+1):
		cy = Y
		for Z in range (-r,r+1):
			cz = Z
			c3D = (cx**2 + cy**2 + cz**2)**(1/2)
			if c3D <= r:
				pontos += 1
print(pontos)
# Out:
# 7
