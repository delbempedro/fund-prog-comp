# %% [markdown]
# Dado um inteiro positivo 0 \lt n \lt 100000<n<10000, faça um programa que calcula a seguinte soma
# S = \frac{1}{n} + \frac{2}{n-1} + \frac{3}{n-2} + \cdots + \frac{n}{1}.
# S=
# n
# 1
# ​
#  +
# n−1
# 2
# ​
#  +
# n−2
# 3
# ​
#  +⋯+
# 1
# n
# ​
#  .
# Neste problema em específico, use 48 casas decimais.

# %%
n = int(input())
# Out:
# 83

# %%
soma = 0

# %%
for s in range (0,n):
	soma = soma + (1 + s)/(n - s)
print("%.48f"%soma)
# Out:
# 337.173734905133983374980743974447250366210937500000
