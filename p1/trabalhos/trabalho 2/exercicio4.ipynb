# %% [markdown]
# Escreva um programa que recebe como entrada a data de nascimento do usuário, e informa qual o seu signo.
# A lista de signos e as datas podem ser encontradas na Wikipédia: Zodíaco.

# %% [markdown]
# # ProgramaSequencial

# %%
dia, mes = input().split("/")
dia, mes = int(dia), int(mes)
# Out:
# 13/05

# %%
#Sagitário
#18 de dezembro a 18 de janeiro
if 18 <= dia and mes == 12:
    print("Sagitário")
if dia <= 18 and mes == 1:
    print("Sagitário")

# %%
#Capricórnio
#19 de janeiro a 15 de fevereiro
if 19 <= dia and mes == 1:
  print("Capricórnio")
if dia <= 15 and mes == 2:
  print("Capricórnio")

# %%
#Aquário
#16 de fevereiro a 11 de março
if 16 <= dia and mes == 2:
  print("Aquário")
if dia <= 11 and mes == 3:
  print("Aquário")

# %%
#Peixes
#12 de março a 18 de abril
if 12 <= dia and mes == 3:
  print("Peixes")
if dia <= 18 and mes == 4:
  print("Peixes")

# %%
#Áries
#19 de abril a 13 de maio
if 19 <= dia and mes == 4:
  print("Áries")
if dia <= 13 and mes == 5:
  print("Áries")
# Out:
# Áries

# %%
#Touro
#14 de maio a 19 de junho
if 14 <= dia and mes == 5:
  print("Touro")
if dia <= 19 and mes == 6:
  print("Touro")

# %%
#Gêmeos
#20 de junho a 20 de julho
if 20 <= dia and mes == 6:
  print("Gêmeos")
if dia <= 20 and mes == 7:
  print("Gêmeos")

# %%
#Câncer
#21 de julho a 9 de agosto
if 21 <= dia and mes == 7:
  print("Câncer")
if dia <= 9 and mes == 8:
  print("Câncer")

# %%
#Leão
#10 de agosto a 15 de setembro
if 10 <= dia and mes == 8:
  print("Leão")
if dia <= 15 and mes == 9:
  print("Leão")

# %%
#Virgem
#16 de setembro a 30 de outubro
if 16 <= dia and mes == 9:
  print("Virgem")
if dia <= 30 and mes == 10:
  print("Virgem")

# %%
#Libra
#31 de outubro a 22 de novembro
if 31 <= dia and mes == 10:
  print("Libra")
if dia <= 22 and mes == 11:
  print("Libra")

# %%
#Escorpião
#23 de novembro a 29 de novembro
if 23 <= dia and mes == 11:
  print("Escorpião")
if dia <= 29 and mes == 11:
  print("Escorpião")

# %%
#Serpentário
#30 de novembro a 17 de dezembro
if 30 <= dia and mes == 11:
  print("Serpentário")
if dia <= 17 and mes == 12:
  print("Serpentário")

# %% [markdown]
# # ProgramaEmCadeia

# %%
dia, mes = input().split("/")
dia, mes = int(dia), int(mes)

#Sagitário
#18 de dezembro a 18 de janeiro
if (18 <= dia and mes == 12) or (dia <= 18 and mes == 1):
    print("Sagitário")

#Capricórnio
#19 de janeiro a 15 de fevereiro
elif (19 <= dia and mes == 1) or (dia <= 15 and mes == 2):
  print("Capricórnio")

#Aquário
#16 de fevereiro a 11 de marÃ§o
elif (16 <= dia and mes == 2) or (dia <= 11 and mes == 3):
  print("Aquário")

#Peixes
#12 de marÃ§o a 18 de abril
elif (12 <= dia and mes == 3) or (dia <= 18 and mes == 4):
  print("Peixes")

#Áries
#19 de abril a 13 de maio
elif (19 <= dia and mes == 4) or (dia <= 13 and mes == 5):
  print("Áries")

#Touro
#14 de maio a 19 de junho
elif (14 <= dia and mes == 5) or (dia <= 19 and mes == 6):
  print("Touro")

#Gêmeos
#20 de junho a 20 de julho
elif (20 <= dia and mes == 6) or (dia <= 20 and mes == 7):
  print("Gêmeos")

#Câncer
#21 de julho a 9 de agosto
elif (21 <= dia and mes == 7) or (dia <= 9 and mes == 8):
  print("Câncer")

#Leão
#10 de agosto a 15 de setembro
elif (10 <= dia and mes == 8) or (dia <= 15 and mes == 9):
  print("Leão")

#Virgem
#16 de setembro a 30 de outubro
elif (16 <= dia and mes == 9) or (dia <= 30 and mes == 10):
  print("Virgem")

#Libra
#31 de outubro a 22 de novembro
elif (31 <= dia and mes == 10) or (dia <= 22 and mes == 11):
  print("Libra")

#Escorpião
#23 de novembro a 29 de novembro
elif (23 <= dia and mes == 11) or (dia <= 29 and mes == 11):
  print("Escorpião")

#Serpentário
#30 de novembro a 17 de dezembro
elif (30 <= dia and mes == 11) or (dia <= 17 and mes == 12):
  print("Serpentário")
# Out:
# 06/04
# Peixes
