# %%
def serie_neymar(n):
    if(n <= 0 ):
        return "SEM RESPOSTA"
    if((n+1) % 2 == 0):
        return int(3 + (n-1)/2 + 4 * ((n-1) / 2))
    return int(3 + 2*n + n/2 - 1)
    
n = int(input())

print(serie_neymar(n))
