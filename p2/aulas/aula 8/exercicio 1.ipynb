# %% [markdown]
# Escreva uma função recursiva que calcula a potência xnx^nxn com n≥0n \geq 0n≥0.

# %%
def pot(x,n):
  if n > 0:
    r = x*pot(x,n-1)
  else:
    r = 1 
  return r

# %%
print(pot(2,10))
# Out:
# 1024
