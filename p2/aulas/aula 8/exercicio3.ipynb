# %% [markdown]
# Faça uma função recursiva que encontra o maior valor de uma lista.

# %%
def maximo(lista):
  if len(lista) != 1:
    if lista[0] < lista[1]:
      r = maximo(lista[1:])
    else:
      r = maximo([lista[0]]+lista[2:])
    return r
  else:
    return lista[0]
