# %% [markdown]
# Faça um programa que calcule o MDC entre dois números usando uma função recursiva chamada MDC.

# %% [markdown]
# #errado

# %%
def MDC(a,b):
  d = 1
  div = []
  if d < min(a,b):
    if a%d == 0 and b%d == 0:
      div.append(d)
    else:
      d += 1
      MDC(a,b)
  return div[-1]

# %%
def MDC(a,b):
  global mi = min(a,b)
  mii = min
  ma = max(a,b)
  if ma%mii != 0 and mi%mii !=0 :
    r = MDC(ma,mii-1)
  else:
    r = mi
  return r

# %% [markdown]
# #certo

# %%
def MDC(a,b):
  mi = min(a,b)
  ma = max(a,b)
  if not ma%mi:
    r = mi
  else:
    x = ma%mi
    r = MDC(mi,x)
  return r

# %%
print(MDC(84,24))
# Out:
# 12
